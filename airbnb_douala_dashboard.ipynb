# %% [markdown]
# <a href="https://colab.research.google.com/github/bellleandracolette-art/airbnb-douala-dashboard/blob/main/airbnb_douala_dashboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Dans une cellule Colab — remplace TON_USERNAME par ton vrai pseudo GitHub
# !git clone https://github.com/bellleandracolette-art/airbnb-douala-dashboard.git
# %cd airbnb-douala-dashboard
# Out:
# Cloning into 'airbnb-douala-dashboard'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (5/5), done.
# /content/airbnb-douala-dashboard

# %%
from google.colab import drive
drive.mount('/content/drive')

# Ensuite clone directement dans ton Drive
import os
os.chdir('/content/drive/MyDrive')
# !git clone https://github.com/bellleandracolette-art/airbnb-douala-dashboard.git
# Out:
# Mounted at /content/drive
# fatal: destination path 'airbnb-douala-dashboard' already exists and is not an empty directory.

# %%
# !mkdir -p data/raw data/processed data/external
# !mkdir -p notebooks
# !mkdir -p src/scraper src/pipeline src/api src/dashboard
# !mkdir -p docs
# !touch requirements.txt config.py

# %%
# !find . -type d | sort
# Out:
# .
# ./airbnb-douala-dashboard
# ./airbnb-douala-dashboard/.git
# ./airbnb-douala-dashboard/.git/branches
# ./airbnb-douala-dashboard/.git/hooks
# ./airbnb-douala-dashboard/.git/info
# ./airbnb-douala-dashboard/.git/logs
# ./airbnb-douala-dashboard/.git/logs/refs
# ./airbnb-douala-dashboard/.git/logs/refs/heads
# ./airbnb-douala-dashboard/.git/logs/refs/remotes
# ./airbnb-douala-dashboard/.git/logs/refs/remotes/origin
# ./airbnb-douala-dashboard/.git/objects
# ./airbnb-douala-dashboard/.git/objects/info
# ./airbnb-douala-dashboard/.git/objects/pack
# ./airbnb-douala-dashboard/.git/refs
# ./airbnb-douala-dashboard/.git/refs/heads
# ./airbnb-douala-dashboard/.git/refs/remotes
# ./airbnb-douala-dashboard/.git/refs/remotes/origin
# ./airbnb-douala-dashboard/.git/refs/tags
# ./Classroom
# ./Classroom/Enseignement Scientifique 1C
# ./Classroom/Mathématiques Expertes
# ./Classroom/Mathématiques Specialité Terminale
# ./Classroom/Maths 1eres
# ./Colab Notebooks
# ./Colab Notebooks/Data
# ...
